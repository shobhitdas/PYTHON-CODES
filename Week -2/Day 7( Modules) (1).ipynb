# %% [markdown]
# ### Built in Functions
#
# ### Modules &  Packages

# %% [markdown]
# #### Built in functions

# %%
# string functions
S=" Saturday"

# %%
len(S)
# Out:
# 9

# %%
bytes(S,'utf-8') #The bytes() function returns a bytes object.
# Out:
# b' Saturday'

# %%
ord(S[1]) 
#The ord() function returns the number representing the unicode code of a specified character.
# Out:
# 83

# %%
# The slice() function returns a slice object.
#specified by range(start, stop, step)
  #start: #Optional. An integer number specifying at which position to start the slicing. Default is 0
  #end: An integer number specifying at which position to end the slicing
  #step: Optional. An integer number specifying the step of the slicing. Default is 1
y=slice(2,5)
S[y]
# slice(3)
# slice(2,4,2)
# Out:
# 'atu'

# %%
id(S)
# Out:
# 1731730623216

# %%
# enumerate
# Enumerate() function adds a counter to an iterable and returns it in a form of enumerating object. 
#This enumerated object can then be used directly for loops or 
#converted into a list of tuples using the list() method.
l1 = ["eat", "sleep", "repeat"]
list(enumerate(l1))
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %%
#### Numeric functions

# %%
# reduce function
# !pip install functools

# %%
from functools import reduce
numbers = [1, 2, 3, 4]

num=reduce(lambda a, b: a + b, numbers)
print(num)
type(num)
# Out:
# 10
# int

# %%
# abs()
x=-21
abs(x)
# Out:
# 21

# %%
#pow()
pow(x,2)
# Out:
# 441

# %% [markdown]
# ### Modules & Packages

# %% [markdown]
# A Python module is a file containing Python definitions and statements.
# A module can define functions, classes, and variables.
# A module can also include runnable code.
# Grouping related code into a module makes the code easier to understand and use.
# It also makes the code logically organized.

# %% [markdown]
# Packages allow you to organize modules in the hierarchical structure.
#
# The way Python organizes packages and modules like the Operating System structures the folders and files.

# %% [markdown]
# #### .py extension
# #### the module contains,
#   - Definitions and implementation of classes
#
#   - variables
#
#   - Functions that can be used inside another program

# %% [markdown]
# ##### To import a package, you use the import statement like this:
#
# import package.module
#
# ##### To access an object from a module that belongs to a package, you use the dot notation:
#
# package.module.function
#
# ##### To make the code more concise, you can use the following statement to import a function
# ##### from a module:
#
# from <module> import <function>

# %%
#### Create a module

# %%
#### create a file with extension .py
### create mymodule.py

# %%
# using 'import'keyword to import module
import mymodule
mymodule.welcome("Ravi")
# Out:
# Hello Ravi

# %%
# create newmodule.py
import newmodule
newmodule.add(1,2)
# Out:
# 3

# %%
newmodule.sub(6,9)
# Out:
# -3

# %%
# create mymodule1
import mymodule2 as new_module

# %%
new_module.person['age']
# Out:
# 34

# %%
new_module.person
# Out:
# {'name': 'Sheetal', 'age': 34}

# %%
# instead of dictionary can use list object
# create module 'module2.py' and create list object instead of dictionary
import module2
module2.person1[3]

# %%
### Built - in - Modules

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Nithya\anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# 17117569 WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa"
# 17142524 INFO: NumExpr defaulting to 8 threads.
# 17156415 INFO: Imported existing <module 'comtypes.gen' from 'C:\\Users\\Nithya\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 17156415 INFO: Using writeable comtypes cache directory: 'C:\Users\Nithya\anaconda3\lib\site-packages\comtypes\gen'
# C:\Users\Nithya\anaconda3\lib\pkgutil.py:93: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\Users\Nithya\anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# 17243406 INFO: QSS file sucessfuly loaded.
# 17243433 INFO: Found application patches to be applied.
# 17243433 WARNING: No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# C:\Users\Nithya\anaconda3\lib\pkgutil.py:108: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              codecs              mpmath              socket
# IPython             codeop              msgpack             socketserver
# MySQLdb             collections         msilib              socks
# OpenSSL             colorama            msvcrt              sockshandler
# PIL                 colorsys            multipledispatch    sortedcollections
# PyInstaller         commctrl            multiprocessing     sortedcontainers
# PyQt5               compileall          munkres             soupsieve
# TBB                 comtypes            mymodule            sphinx
# __future__          concurrent          mymodule1           sphinxcontrib
# _abc                conda               mymodule2           spyder
# _aix_support        conda_build         mypy_extensions     spyder_kernels
# _ast                conda_content_trust mysql               sqlalchemy
# _asyncio            conda_env           mysqlx              sqlite3
# _bisect             conda_pack          nacl                sre_compile
# _black_version      conda_package_handling navigator_updater   sre_constants
# _blake2             conda_token         nbclassic           sre_parse
# _bootlocale         conda_verify        nbclient            ssl
# _bootsubprocess     configparser        nbconvert           sspi
# _bz2                contextlib          nbformat            sspicon
# _cffi_backend       contextlib2         nest_asyncio        stat
# _codecs             contextvars         netbios             statistics
# _codecs_cn          cookiecutter        netrc               statsmodels
# _codecs_hk          copy                networkx            storemagic
# _codecs_iso2022     copyreg             newmodule           string
# _codecs_jp          crypt               nltk                stringprep
# _codecs_kr          cryptography        nntplib             struct
# _codecs_tw          csv                 nose                subprocess
# _collections        ctypes              notebook            sunau
# _collections_abc    curl                nt                  symbol
# _compat_pickle      curses              ntpath              sympy
# _compression        cwp                 ntsecuritycon       sympyprinting
# _contextvars        cycler              nturl2path          symtable
# _csv                cython              numba               sys
# _ctypes             cythonmagic         numbers             sysconfig
# _ctypes_test        cytoolz             numexpr             tables
# _daal4py            daal4py             numpy               tabnanny
# _datetime           dask                numpydoc            tarfile
# _decimal            dataclasses         odbc                tbb
# _distutils_hack     datacompy           olefile             tblib
# _elementtree        datetime            onedal              telnetlib
# _functools          dateutil            opcode              tempfile
# _hashlib            dbi                 openpyxl            terminado
# _heapq              dbm                 operator            test
# _imp                dde                 optparse            test_data
# _io                 debugpy             ordered_set         test_pycosat
# _json               decimal             ordlookup           testpath
# _locale             decorator           os                  tests
# _lsprof             defusedxml          outcome             tests_negative
# _lzma               diff_match_patch    packaging           text_unidecode
# _markupbase         difflib             pandas              textdistance
# _md5                dis                 pandocfilters       textwrap
# _msi                distributed         paramiko            this
# _multibytecodec     distutils           parser              threading
# _multiprocessing    doctest             parso               threadpoolctl
# _nsis               docutils            partd               three_merge
# _onedal4py_host     dotenv              past                tifffile
# _opcode             eel                 path                time
# _operator           email               pathlib             timeit
# _osx_support        encodings           pathlib2            timer
# _overlapped         ensurepip           pathspec            tinycss
# _peg_parser         entrypoints         patsy               tkinter
# _pickle             enum                pdb                 tlz
# _py_abc             erfa                pefile              token
# _pydecimal          errno               pep8                tokenize
# _pyinstaller_hooks_contrib et_xmlfile          perfmon             toml
# _pyio               fake_useragent      peutils             toolz
# _pyrsistent_version fastcache           pexpect             tornado
# _pytest             faulthandler        pickle              tqdm
# _queue              filecmp             pickleshare         trace
# _random             fileinput           pickletools         traceback
# _sha1               filelock            pip                 tracemalloc
# _sha256             flake8              pipes               traitlets
# _sha3               flask               pkg_resources       trio
# _sha512             fnmatch             pkginfo             trio_websocket
# _signal             fontTools           pkgutil             tty
# _sitebuiltins       formatter           platform            turtle
# _socket             fractions           playsound           turtledemo
# _sqlite3            fsspec              plistlib            typed_ast
# _sre                ftplib              pluggy              types
# _ssl                functools           ply                 typing
# _stat               future              poplib              typing_extensions
# _statistics         gc                  posixpath           ujson
# _string             genericpath         poyo                unicodecsv
# _strptime           getopt              pprint              unicodedata
# _struct             getpass             profile             unidecode
# _symtable           gettext             prometheus_client   unittest
# _system_path        gevent              prompt_toolkit      urllib
# _testbuffer         geventwebsocket     pstats              urllib3
# _testcapi           glob                psutil              uu
# _testconsole        glob2               pty                 uuid
# _testimportmultiple graphlib            ptyprocess          venv
# _testinternalcapi   greenlet            pvectorc            warnings
# _testmultiphase     gzip                py                  watchdog
# _thread             h11                 py_compile          wave
# _threading_local    h5py                pyasn1              wcwidth
# _tkinter            hashlib             pyclbr              weakref
# _tracemalloc        heapdict            pycodestyle         webbrowser
# _uuid               heapq               pycosat             webdriver_manager
# _warnings           hmac                pycparser           webencodings
# _weakref            html                pycurl              werkzeug
# _weakrefset         html5lib            pydoc               wheel
# _win32sysloader     http                pydoc_data          whichcraft
# _winapi             idlelib             pydocstyle          widgetsnbextension
# _winxptheme         idna                pyexpat             win2kras
# _xxsubinterpreters  imagecodecs         pyflakes            win32api
# _yaml               imageio             pygments            win32clipboard
# _zoneinfo           imagesize           pylab               win32com
# abc                 imaplib             pylint              win32con
# adodbapi            imblearn            pyls_spyder         win32console
# afxres              imghdr              pylsp               win32cred
# aifc                imp                 pylsp_black         win32crypt
# alabaster           importlib           pylsp_jsonrpc       win32cryptcon
# altgraph            importlib_metadata  pyodbc              win32ctypes
# anaconda_navigator  inflection          pyparsing           win32event
# anaconda_project    iniconfig           pyreadline          win32evtlog
# antigravity         inspect             pyrsistent          win32evtlogutil
# anyio               intervaltree        pytest              win32file
# appdirs             io                  pythoncom           win32gui
# argh                ipaddress           pytz                win32gui_struct
# argon2              ipykernel           pywin               win32help
# argparse            ipykernel_launcher  pywin32_bootstrap   win32inet
# array               ipython_genutils    pywin32_testutil    win32inetcon
# arrow               ipywidgets          pywintypes          win32job
# asn1crypto          isapi               pywt                win32lz
# ast                 isort               pyximport           win32net
# astroid             isympy              qdarkstyle          win32netcon
# astropy             itertools           qstylizer           win32pdh
# async_generator     itsdangerous        qtawesome           win32pdhquery
# asynchat            jdcal               qtconsole           win32pdhutil
# asyncio             jedi                qtpy                win32pipe
# asyncore            jinja2              queue               win32print
# atexit              jinja2_time         quopri              win32process
# atomicwrites        jmespath            random              win32profile
# attr                joblib              rasutil             win32ras
# audioop             json                re                  win32rcparser
# auto_py_to_exe      json5               readline            win32security
# autopep8            jsonschema          regcheck            win32service
# autoreload          jupyter             regex               win32serviceutil
# awscli              jupyter_client      regutil             win32timezone
# babel               jupyter_console     repo_cli            win32trace
# backcall            jupyter_core        reprlib             win32traceutil
# backports           jupyter_server      requests            win32transaction
# base64              jupyterlab          researchpy          win32ts
# bcrypt              jupyterlab_pygments rlcompleter         win32ui
# bdb                 jupyterlab_server   rmagic              win32uiole
# binaryornot         jupyterlab_widgets  rope                win32verstamp
# binascii            jwt                 rsa                 win32wnet
# binhex              keyring             rtree               win_inet_pton
# binstar_client      keyword             ruamel_yaml         win_unicode_console
# bisect              kiwisolver          run                 wincertstore
# bitarray            lazy_object_proxy   runpy               winerror
# bkcharts            lib2to3             s3transfer          winioctlcon
# black               libarchive          sched               winnt
# blackd              libfuturize         scipy               winperf
# bleach              libpasteurize       scripts             winpty
# blib2to3            lief                seaborn             winreg
# bokeh               linecache           secrets             winsound
# boto                llvmlite            select              winxpgui
# boto3               locale              selectors           winxptheme
# botocore            locket              selenium            wrapt
# bottle              logging             send2trash          wsgiref
# bottle_websocket    lxml                servicemanager      wsproto
# bottleneck          lzma                setuptools          xdrlib
# brotli              mailbox             shelve              xlrd
# bs4                 mailcap             shlex               xlsxwriter
# builtins            markupsafe          shutil              xlwings
# bz2                 marshal             signal              xlwt
# cProfile            math                simplegeneric       xml
# cached_property     matplotlib          singledispatch      xmlrpc
# calendar            matplotlib_inline   sip                 xmltodict
# certifi             mccabe              sipconfig           xxsubtype
# cffi                menuinst            sipdistutils        yaml
# cgi                 mimetypes           site                yapf
# cgitb               mistune             six                 yapftests
# chardet             mkl                 skimage             zict
# charset_normalizer  mkl_fft             sklearn             zipapp
# chunk               mkl_random          sklearnex           zipfile
# click               mmap                slugify             zipimport
# cloudpickle         mmapfile            smtpd               zipp
# clyent              mmsystem            smtplib             zlib
# cmath               mock                sndhdr              zmq
# cmd                 modulefinder        sniffio             zoneinfo
# code                more_itertools      snowballstemmer     zope
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# math 
# statistics
# sys
# os
# time
# pickle
# csv
# datetime
# random

# %%
#math
import math
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.radians(30)
# Out:
# 0.5235987755982988

# %%
# statistics
import statistics
statistics.mean([2,5,6,9])
# Out:
# 5.5

# %%
statistics.median([2,5,6,9])
# Out:
# 5.5

# %%
statistics.stdev([2,5,6,9])
# Out:
# 2.886751345948129

# %%
# sys
import sys
sys.version
# Out:
# '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
# os
import os
#view working directory
os.getcwd()
# Out:
# 'C:\\Users\\Nithya\\Deloitte -  Tech - Python\\Week 2'

# %%
# changing working directory
os.chdir("D://Files")

# %%
os.getcwd()
# Out:
# 'D:\\Files'

# %%
#make directory
os.mkdir("MyProjectProject1")

# %%
# pickle
import pickle
data=['one',2,3,5]
with open('data.txt','wb') as f:
    pickle.dump(data,f)

# %%
with open('data.txt','rb') as f:
    L=f.readlines()
print(L)
# Out:
# [b'\x80\x04\x95\x11\x00\x00\x00\x00\x00\x00\x00]\x94(\x8c\x03one\x94K\x02K\x03K\x05e.']

# %%
#csv
import csv
# reading csv files using csv.reader()
c=open("oj.csv",'r')
o=csv.reader(c)
for r in o:
    print(r)
# Out:
# ['store', 'brand', 'week', 'logmove', 'feat', 'price', 'AGE60', 'EDUC', 'ETHNIC', 'INCOME', 'HHLARGE', 'WORKWOM', 'HVAL150', 'SSTRDIST', 'SSTRVOL', 'CPDIST5', 'CPWVOL5']
# ['2', 'tropicana', '40', '9.018695488', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '46', '8.723231275', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '47', '8.253227646', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '48', '8.987196821', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '50', '9.093357017', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '51', '8.877381955', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '52', '9.29468152', '0', '3.29', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '53', '8.954673629', '0', '3.29', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '54', '9.049232212', '0', '3.29', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '57', '8.61323038', '0', '3.29', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '58', '8.68067166', '0', '3.56', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '59', '9.034080407', '0', '3.56', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '60', '8.691482577', '0', '3.56', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '61', '8.831711918', '0', '3.56', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '62', '9.128696383', '0', '3.87', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '63', '9.405907156', '0', '2.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '64', '9.447150114', '0', '2.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '65', '8.783855897', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '66', '8.723231275', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '67', '9.957975738', '0', '2.39', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '68', '9.426741242', '0', '2.39', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '69', '9.156095357', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '70', '9.793672687', '0', '2.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '71', '9.14931567', '0', '2.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '72', '8.743850562', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '73', '8.841014311', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '74', '9.727227587', '0', '2.49', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '75', '8.743850562', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '76', '8.979164649', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '77', '8.723231275', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '78', '8.979164649', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '79', '8.962904128', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '80', '8.712759975', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '81', '10.64960662', '1', '1.69', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '82', '8.502688505', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '83', '10.29228113', '1', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '84', '9.208739091', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '85', '10.46880136', '1', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '86', '10.08313888', '0', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '87', '8.868413285', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '88', '10.10691807', '1', '2.29', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '89', '8.754002934', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '90', '8.712759975', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '91', '10.42037477', '0', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '92', '9.491601877', '0', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '93', '8.733594062', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '94', '9.270870872', '0', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '95', '10.70710219', '0', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '97', '9.908276069', '0', '1.99', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '98', '9.121727714', '1', '3.59', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '99', '9.996613531', '0', '2.19', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana', '100', '9.515469358', '0', '2.19', '0.232864734', '0.248934934', '0.114279949', '10.55320518', '0.103953406', '0.303585347', '0.463887065', '2.110122129', '1.142857143', '1.927279669', '0.376926613']
# ['2', 'tropicana',
'0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '77', '10.86084345', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '78', '8.636219898', '0', '2.17', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '79', '10.28575227', '0', '2.17', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '80', '12.12129876', '1', '1.69', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '81', '10.27698028', '0', '1.69', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '86', '10.1774763', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '87', '12.27380606', '1', '1.39', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '88', '9.529521112', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '89', '9.442086812', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '90', '9.426741242', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '91', '9.462187991', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '92', '11.09813703', '1', '1.49', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '93', '10.18956834', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '94', '11.62967686', '1', '1.69', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '95', '10.28793329', '0', '1.69', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '96', '9.323669057', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '97', '9.700146629', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '98', '9.329367078', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '99', '9.215128889', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '100', '9.252633284', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '101', '10.82711133', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '102', '11.95370624', '1', '1.29', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '103', '9.566054855', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '104', '9.335032816', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '105', '10.93424917', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '106', '9.431882642', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '107', '10.31161578', '0', '1.89', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '108', '9.898675996', '0', '1.79', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '109', '9.761001904', '0', '1.79', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '110', '12.91949293', '1', '1.69', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '111', '9.538780437', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '112', '11.08937785', '0', '1.49', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '113', '10.30948585', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '114', '9.561560465', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '115', '9.727227587', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '116', '9.346268889', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '117', '9.395325046', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '118', '9.142489705', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '119', '9.162829389', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '120', '9.481893063', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '121', '10.2156671', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '122', '8.793612072', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '123', '10.11212642', '1', '2.49', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '124', '9.749870064', '1', '2.49', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '125', '8.565602331', '0', '2.49', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '126', '8.624791202', '0', '2.39', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '127', '8.912473275', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '128', '12.09554324', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '129', '10.17990643', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '130', '9.384629757', '0', '2.39', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '131', '10.20625526', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '132', '10.07238609', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '133', '10.56741187', '0', '2.39', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '134', '9.89222436', '1', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '135', '9.757305042', '0', '1.99', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '136', '9.018695488', '0', '2.39', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# ['73', 'minute.maid', '137', '10.912321', '1', '1.79', '0.257450782', '0.07305396', '0.109213291', '10.61496569', '0.135340763', '0.292748225', '0.005144033', '2.584605038', '1.5', '3.228630183', '0.18318752']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
c.close()

# %%
p=[(2,3,4),('Python',3000,4000)]
c=open('newfile.csv','w',newline='')
o=csv.writer(c)
for i in p:
    print(i)
    o.writerow(i)
c.close()
# Out:
# (2, 3, 4)
# ('Python', 3000, 4000)

# %%
c=open('newfile.csv','r')
o=csv.reader(c)
for r in o:
    print(r)
# Out:
# ['2', '3', '4']
# ['Python', '3000', '4000']

# %%
#random
import random
#generate random floats
random.random()
# Out:
# 0.8648781139813367

# %%
# generate random integers
random.randint(1,100)
# Out:
# 32

# %%
#select random elements
random.choice('computer')
# Out:
# 't'

# %%
#generate random numbers within range
x=random.randrange(1,10,2) # (start,stop,step)[1,3,5,7,9]
x
# random.randrange(1,10) # by default skip =1--> contains all the numbers between 1 to 10.
# Out:
# 9

# %%
from datetime import date
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-07-26

# %%
#### Modules Vs Packages

# %% [markdown]
# Module: The module is a simple Python file that contains collections of functions and global variables and with having a .py extension file. It is an executable file and to organize all the modules we have the concept called Package in Python.
#
# Package: The package is a simple directory having collections of modules. This directory contains Python modules and also having __init__.py file by which the interpreter interprets it as a Package. The package is simply a namespace. The package also contains sub-packages inside it.
